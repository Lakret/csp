# %%
import sys
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install bokeh
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install matplotlib

# %%
import pandas as pd
import matplotlib as plt
from matplotlib import rcParams

# set default font
rcParams['font.family'] = 'monospace'
rcParams['font.monospace'] = ['Fira Code']

df = pd.read_csv('results/backtracking_benchmark.csv')
df
# Out:
#                    Name              Input  Iterations per Second  \
# 0  backtracking_default  10 Queens optimal              43.990746
# 1  backtracking_default  12 Queens optimal              10.520304
# 2  backtracking_default  14 Queens optimal               0.916186
# 3  backtracking_default  16 Queens optimal               0.111635
# 4  backtracking_default   4 Queens optimal            8436.688917
# 5  backtracking_default   6 Queens optimal             625.725873
# 6  backtracking_default   8 Queens optimal              72.206276
#
#    Standard Deviation Iterations Per Second  Run Time Average  \
# 0                                  4.907108      2.273205e+07
# 1                                  0.557901      9.505429e+07
# 2                                  0.032073      1.091481e+09
# 3                                  0.000000      8.957776e+09
# 4                               1364.957480      1.185299e+05
# 5                                 64.768902      1.598144e+06
# ...

# %% [markdown]
# ## Boxplots for performance comparision

# %%
df = pd.read_csv('results/backtracking_benchmark_raw.csv')
# convert from nanoseconds to milliseconds
df = df.applymap(lambda value: value / 1_000_000)
df
# Out:
#        backtracking_default with input 10 Queens optimal (Run Time Measurements)  \
# 0                                               20.61799
# 1                                               20.32799
# 2                                               20.19199
# 3                                               20.44999
# 4                                               20.78899
# ...                                                  ...
# 41874                                                NaN
# 41875                                                NaN
# 41876                                                NaN
# 41877                                                NaN
# 41878                                                NaN
#
#        backtracking_default with input 10 Queens optimal (Memory Usage Measurements)  \
# 0                                                    NaN
# 1                                                    NaN
# ...

# %%
# throwing away memory measurements for now
columns = [column for column in df.columns if 'Memory Usage Measurements' not in column]
df = df.loc[:, columns]
# simplify labels
df = df.rename(columns=lambda column_name: column_name.replace(' (Run Time Measurements)', '').replace(' with input ', ' ').replace('backtracking_', ''))

df
# Out:
#        default 10 Queens optimal  default 12 Queens optimal  \
# 0                       20.61799                   85.84199
# 1                       20.32799                   86.94099
# 2                       20.19199                   87.75699
# 3                       20.44999                   86.81699
# 4                       20.78899                   87.74999
# ...                          ...                        ...
# 41874                        NaN                        NaN
# 41875                        NaN                        NaN
# 41876                        NaN                        NaN
# 41877                        NaN                        NaN
# 41878                        NaN                        NaN
#
#        default 14 Queens optimal  default 16 Queens optimal  \
# 0                     1042.45599                 8957.77599
# 1                     1100.10299                        NaN
# 2                     1146.00699                        NaN
# ...

# %%
backtracking_10_optimal_default = df.loc[:, ['default 10 Queens optimal']].dropna(axis=0)

b10 = backtracking_10_optimal_default.plot.box(showfliers=False)
b10.set_ylabel('ms')
b10.set_title('10 Queens')
b10

# %%
# backtracking_10_slower_default = df.loc[:, ['default 10 Queens slower']].dropna(axis=0)

# b10_slower = backtracking_10_slower_default.plot.box(showfliers=False)
# b10_slower.set_ylabel('ms')
# b10_slower.set_title('10 Queens')
# b10_slower

# %%
medians_optimal = df.loc[:, ['default 4 Queens optimal', 'default 6 Queens optimal', 'default 8 Queens optimal', 'default 10 Queens optimal', 'default 12 Queens optimal', 'default 14 Queens optimal', 'default 16 Queens optimal']].median().copy()
medians_optimal = medians_optimal.rename(lambda name: int(name.replace('default ', '').replace(' Queens optimal', '')))
medians_optimal
# Out:
# 4        0.11899
# 6        1.56999
# 8       13.71599
# 10      22.16049
# 12      95.57999
# 14    1096.44299
# 16    8957.77599
# dtype: float64

# %%
medians_plot = medians_optimal.plot(marker='D', linewidth=0.0, color='#ff00ff')
medians_plot.set_ylabel('Execution time (ms)')
medians_plot.set_xlabel('# of queens')
medians_plot.set_title('N Queens execution time by N', color='#0100ff')
# Out:
# Text(0.5, 1.0, 'N Queens execution time by N')

# %%
log_medians_plot = medians_optimal.plot(marker='D', linewidth=0.0, logy=True, color='#ff00ff')
log_medians_plot.set_ylabel('Execution time (ms)')
log_medians_plot.set_xlabel('# of queens')
log_medians_plot.set_title('N Queens execution time by N (logarithmic)', color='#0100ff')
log_medians_plot

# %% [markdown]
# ## Comparing representations

# %%
df = pd.read_csv('results/backtracking_benchmark_with_slower.csv')
df
# Out:
#                    Name              Input  Iterations per Second  \
# 0  backtracking_default  10 Queens optimal              48.756801
# 1  backtracking_default   10 Queens slower               0.482609
# 2  backtracking_default  12 Queens optimal              11.747716
# 3  backtracking_default   12 Queens slower               0.090171
# 4  backtracking_default   4 Queens optimal            9078.890994
# 5  backtracking_default    4 Queens slower             343.346334
# 6  backtracking_default   8 Queens optimal              83.281025
# 7  backtracking_default    8 Queens slower               1.000514
#
#    Standard Deviation Iterations Per Second  Run Time Average  \
# 0                                  5.634485      2.050996e+07
# 1                                  0.011993      2.072072e+09
# 2                                  0.324948      8.512293e+07
# 3                                  0.000000      1.109010e+10
# ...

# %%
df_optimal_by_size = df \
    .loc[(df['Name'] == 'backtracking_default') & (df['Input'].str.contains('optimal')), ['Input', 'Run Time Median']] \
    .sort_values(by='Run Time Median') \
    .copy() \
    .replace(to_replace='(\d+) Queens optimal', value='\\1', regex=True)

df_optimal_by_size['Input'] = df_optimal_by_size['Input'].apply(lambda x: int(x))
df_optimal_by_size['Run Time Median'] = df_optimal_by_size['Run Time Median'].apply(lambda x: x / 1_000_000.0)

df_optimal_by_size
# Out:
#    Input  Run Time Median
# 4      4           0.1010
# 6      8          11.9150
# 0     10          19.8535
# 2     12          84.5940

# %%
df_slower_by_size = df \
    .loc[(df['Name'] == 'backtracking_default') & (df['Input'].str.contains('slower')), ['Input', 'Run Time Median']] \
    .sort_values(by='Run Time Median') \
    .copy() \
    .replace(to_replace='(\d+) Queens slower', value='\\1', regex=True)

df_slower_by_size['Input'] = df_slower_by_size['Input'].apply(lambda x: int(x))
df_slower_by_size['Run Time Median'] = df_slower_by_size['Run Time Median'].apply(lambda x: x / 1_000_000.0)

df_slower_by_size
# Out:
#    Input  Run Time Median
# 5      4           2.8630
# 7      8        1001.4465
# 1     10        2100.0620
# 3     12       11090.1000

# %%
df_optimal_vs_slower_by_size = df_optimal_by_size.set_index('Input').join(df_slower_by_size.set_index('Input'), how='left', rsuffix=' (slower)')

df_optimal_vs_slower_by_size.columns = ['Optimal representation', 'Alternative representation']
df_optimal_vs_slower_by_size
# Out:
#        Optimal representation  Alternative representation
# Input
# 4                      0.1010                      2.8630
# 8                     11.9150                   1001.4465
# 10                    19.8535                   2100.0620
# 12                    84.5940                  11090.1000

# %%
representations_plot = df_optimal_vs_slower_by_size.plot(marker='D', linewidth=0.0, color=['#ff00ff', '#ff0000'])


representations_plot.set_ylabel('Execution time (ms)')
representations_plot.set_xlabel('# of queens')
representations_plot.set_title('N Queens execution time by N', color='#0100ff')
# Out:
# Text(0.5, 1.0, 'N Queens execution time by N')

# %%
representations_log_plot = df_optimal_vs_slower_by_size.plot(marker='D', linewidth=0.0, logy=True, color=['#ff00ff', '#ff0000'])

representations_log_plot.set_ylabel('Execution time (ms)')
representations_log_plot.set_xlabel('# of queens')
representations_log_plot.set_title('N Queens execution time by N (lograithmic)', color='#0100ff')
# Out:
# Text(0.5, 1.0, 'N Queens execution time by N (lograithmic)')
